# %%
import pandas as pd
import math as m
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',100)

# %%
grad_2022 = pd.read_csv('D:\GitHub\Intro-to-DS-AI-codes\exam practice\diemthithpt2022.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5272\2218345855.py:1: SyntaxWarning: invalid escape sequence '\G'
#   grad_2022 = pd.read_csv('D:\GitHub\Intro-to-DS-AI-codes\exam practice\diemthithpt2022.csv')

# %%
city = {
    '01': 'THÀNH PHỐ HÀ NỘI',
    '02': 'THÀNH PHỐ HỒ CHÍ MINH',
    '03': 'THÀNH PHỐ HẢI PHÒNG',
    '04': 'THÀNH PHỐ ĐÀ NẴNG',
    '05': 'TỈNH HÀ GIANG',
    '06': 'TỈNH CAO BẰNG',
    '07': 'TỈNH LAI CHÂU',
    '08': 'TỈNH LÀO CAI',
    '09': 'TỈNH TUYÊN QUANG',
    '10': 'TỈNH LẠNG SƠN',
    '11': 'TỈNH BẮC KẠN',
    '12': 'TỈNH THÁI NGUYÊN',
    '13': 'TỈNH YÊN BÁI',
    '14': 'TỈNH SƠN LA',
    '15': 'TỈNH PHÚ THỌ',
    '16': 'TỈNH VĨNH PHÚC',
    '17': 'TỈNH QUẢNG NINH',
    '18': 'TỈNH BẮC GIANG',
    '19': 'TỈNH BẮC NINH',
    '21': 'TỈNH HẢI DƯƠNG',
    '22': 'TỈNH HƯNG YÊN',
    '23': 'TỈNH HÒA BÌNH',
    '24': 'TỈNH HÀ NAM',
    '25': 'TỈNH NAM ĐỊNH',
    '26': 'TỈNH THÁI BÌNH',
    '27': 'TỈNH NINH BÌNH',
    '28': 'TỈNH THANH HÓA',
    '29': 'TỈNH NGHỆ AN',
    '30': 'TỈNH HÀ TĨNH',
    '31': 'TỈNH QUẢNG BÌNH',
    '32': 'TỈNH QUẢNG TRỊ',
    '33': 'TỈNH THỪA THIÊN HUẾ',
    '34': 'TỈNH QUẢNG NAM',
    '35': 'TỈNH QUẢNG NGÃI',
    '36': 'TỈNH KON TUM',
    '37': 'TỈNH BÌNH ĐỊNH',
    '38': 'TỈNH GIA LAI',
    '39': 'TỈNH PHÚ YÊN',
    '40': 'TỈNH ĐẮK LẮK',
    '41': 'TỈNH KHÁNH HÒA',
    '42': 'TỈNH LÂM ĐỒNG',
    '43': 'TỈNH BÌNH PHƯỚC',
    '44': 'TỈNH BÌNH DƯƠNG',
    '45': 'TỈNH NINH THUẬN',
    '46': 'TỈNH TÂY NINH',
    '47': 'TỈNH BÌNH THUẬN',
    '48': 'TỈNH ĐỒNG NAI',
    '49': 'TỈNH LONG AN',
    '50': 'TỈNH ĐỒNG THÁP',
    '51': 'TỈNH AN GIANG',
    '52': 'TỈNH BÀ RỊA VŨNG TÀU',
    '53': 'TỈNH TIỀN GIANG',
    '54': 'TỈNH KIÊN GIANG',
    '55': 'THÀNH PHỐ CẦN THƠ',
    '56': 'TỈNH BẾN TRE',
    '57': 'TỈNH VĨNH LONG',
    '58': 'TỈNH TRÀ VINH',
    '59': 'TỈNH SÓC TRĂNG',
    '60': 'TỈNH BẠC LIÊU',
    '61': 'TỈNH CÀ MAU',
    '62': 'TỈNH ĐIỆN BIÊN',
    '63' : 'TỈNH ĐĂK NÔNG',
    '64' : 'TỈNH HẬU GIANG'
}

# %%
grad_2022

# %%
grad_2022.columns

subjects = ['toan', 'ngu_van', 'ngoai_ngu', 'vat_li', 'hoa_hoc', 'sinh_hoc',
       'lich_su', 'dia_li', 'gdcd']

natural_sciences = ['vat_li', 'hoa_hoc', 'sinh_hoc']
social_sciences = ['lich_su', 'dia_li', 'gdcd']

# %%
#convert id to str add 0 if len<8 (cuz id is len =8)
# for i in range(grad_2022.shape[0]):
#     grad_2022['sbd'][i] = str(int(grad_2022['sbd'][i]))
#     if len(grad_2022['sbd'][i])<8:
#         grad_2022['sbd'][i] = '0' + grad_2022['sbd'][i]

grad_2022['sbd'] = grad_2022['sbd'].astype(str).str.zfill(8)

# %%
grad_2022['SGD'] = grad_2022['sbd'].str[:2].map(city)

# %%
grad_2022.describe().iloc[:,1:9]
# Out:
#              ngu_van      ngoai_ngu         vat_li        hoa_hoc  \
# count  981407.000000  870609.000000  325523.000000  327367.000000
# mean        6.507746       5.157686       6.723779       6.703898
# std         1.379602       1.949547       1.441925       1.600393
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.580000       3.600000       5.750000       5.500000
# 50%         6.500000       4.800000       7.000000       7.000000
# 75%         7.500000       6.600000       7.750000       8.000000
# max        10.000000      10.000000      10.000000      10.000000
#
#             sinh_hoc        lich_su         dia_li           gdcd
# count  322198.000000  659662.000000  657421.000000  554343.000000
# mean        5.019109       6.343930       6.677929       8.033266
# std         1.448270       1.612879       1.215013       1.067272
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
grad_2022.head()
# Out:
#         sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0  01000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1  01000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2  01000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3  01000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4  01000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_li  gdcd               SGD
# 0     6.0  8.75  THÀNH PHỐ HÀ NỘI
# 1     7.5  8.25  THÀNH PHỐ HÀ NỘI
# 2     5.5  8.75  THÀNH PHỐ HÀ NỘI
# 3     6.5  7.50  THÀNH PHỐ HÀ NỘI
# 4     8.5  8.25  THÀNH PHỐ HÀ NỘI

# %%
grad_2022.tail()
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 995436  64006584   8.4     6.75        4.6     NaN      NaN       NaN
# 995437  64006585   5.6     6.50        2.8     NaN      NaN       NaN
# 995438  64006586   5.8     6.00        6.6     NaN      NaN       NaN
# 995439  64006587   7.6     6.75        7.0     NaN      NaN       NaN
# 995440  64006588   6.6     4.50        3.2     NaN      NaN       NaN
#
#         lich_su  dia_li  gdcd             SGD
# 995436     6.50    6.75  9.00  TỈNH HẬU GIANG
# 995437     6.25    6.75  8.50  TỈNH HẬU GIANG
# 995438     7.25    8.00  8.00  TỈNH HẬU GIANG
# 995439     8.75    7.25  9.75  TỈNH HẬU GIANG
# 995440     3.00    6.00  7.50  TỈNH HẬU GIANG

# %%
split = grad_2022.loc[:,subjects].fillna(-1)
#grad_2022 = grad_2022.drop(columns=subjects)
#grad_2022 = pd.concat([grad_2022,split], axis=1)
grad_2022

# %%
grad_2022.groupby(by=['SGD']).size().sort_values(ascending=False)
# Out:
# SGD
# THÀNH PHỐ HÀ NỘI         96942
# THÀNH PHỐ HỒ CHÍ MINH    84596
# TỈNH THANH HÓA           37466
# TỈNH NGHỆ AN             36564
# TỈNH ĐỒNG NAI            31363
# THÀNH PHỐ HẢI PHÒNG      22399
# TỈNH BẮC GIANG           20553
# TỈNH HẢI DƯƠNG           20422
# TỈNH ĐẮK LẮK             20348
# TỈNH THÁI BÌNH           20145
# TỈNH NAM ĐỊNH            19769
# TỈNH AN GIANG            18574
# TỈNH BÌNH ĐỊNH           18489
# TỈNH HÀ TĨNH             17304
# TỈNH QUẢNG NAM           16739
# TỈNH BẮC NINH            15850
# TỈNH PHÚ THỌ             15808
# TỈNH QUẢNG NINH          15624
# TỈNH LONG AN             15321
# TỈNH THÁI NGUYÊN         15083
# TỈNH ĐỒNG THÁP           15038
# TỈNH TIỀN GIANG          15028
# TỈNH KIÊN GIANG          14325
# TỈNH LÂM ĐỒNG            14102
# TỈNH GIA LAI             14075
# TỈNH KHÁNH HÒA           14025
# TỈNH HƯNG YÊN            13885
# TỈNH VĨNH PHÚC           13873
# TỈNH THỪA THIÊN HUẾ      13296
# TỈNH QUẢNG NGÃI          13295
# ...

# %%
#use condition to find result of all student in [sgd]
cond = (grad_2022['SGD']=='TỈNH THỪA THIÊN HUẾ')
grad_2022.loc[cond,:]

# %%
#calculate total combined
grad_2022['total'] = grad_2022[subjects].sum(axis=1)
grad_2022.head()
# Out:
#         sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0  01000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1  01000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2  01000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3  01000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4  01000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_li  gdcd               SGD  total
# 0     6.0  8.75  THÀNH PHỐ HÀ NỘI  30.10
# 1     7.5  8.25  THÀNH PHỐ HÀ NỘI  47.00
# 2     5.5  8.75  THÀNH PHỐ HÀ NỘI  39.80
# 3     6.5  7.50  THÀNH PHỐ HÀ NỘI  45.00
# 4     8.5  8.25  THÀNH PHỐ HÀ NỘI  49.45

# %%
top50 = grad_2022.sort_values(by=['total'],ascending=False).head(50)
top50.groupby(by=['SGD']).size().sort_values(ascending=False)
top50
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 474053  27005570   9.2     9.25        9.4     NaN      NaN       NaN
# 500312  28021467   9.0     9.00        9.8     NaN      NaN       NaN
# 188531  03007010   9.2     9.50        9.8     NaN      NaN       NaN
# 433190  25004612   8.8     9.50        9.4     NaN      NaN       NaN
# 312338  16002721   9.6     9.50        9.8     NaN      NaN       NaN
# 951160  59002654   8.6     9.00        9.8     NaN      NaN       NaN
# 429108  25000513   9.0     9.25        9.6     NaN      NaN       NaN
# 888112  53013255   8.2     9.25        9.8     NaN      NaN       NaN
# 188010  03006489   8.4     9.50        9.8     NaN      NaN       NaN
# 193885  03012404   9.2     9.25        9.2     NaN      NaN       NaN
# 181675  03000138   9.2     9.75        9.2     NaN      NaN       NaN
# 702736  41000792   9.2     8.75        9.4     NaN      NaN       NaN
# ...

# %%
bot50 = grad_2022.sort_values(by=['total'],ascending=False).tail(50)
bot50.groupby(by=['SGD']).size().sort_values(ascending=False)
# Out:
# SGD
# THÀNH PHỐ HỒ CHÍ MINH    5
# TỈNH THANH HÓA           4
# THÀNH PHỐ HÀ NỘI         4
# TỈNH NGHỆ AN             3
# TỈNH BẮC GIANG           3
# TỈNH LONG AN             3
# TỈNH KIÊN GIANG          2
# TỈNH CAO BẰNG            2
# THÀNH PHỐ CẦN THƠ        2
# TỈNH BÀ RỊA VŨNG TÀU     2
# THÀNH PHỐ ĐÀ NẴNG        2
# TỈNH BÌNH ĐỊNH           1
# TỈNH THÁI BÌNH           1
# TỈNH ĐỒNG NAI            1
# TỈNH ĐẮK LẮK             1
# TỈNH ĐĂK NÔNG            1
# TỈNH YÊN BÁI             1
# TỈNH VĨNH PHÚC           1
# TỈNH TUYÊN QUANG         1
# TỈNH THỪA THIÊN HUẾ      1
# THÀNH PHỐ HẢI PHÒNG      1
# TỈNH HƯNG YÊN            1
# TỈNH SƠN LA              1
# TỈNH QUẢNG NINH          1
# TỈNH QUẢNG NAM           1
# TỈNH PHÚ THỌ             1
# TỈNH NAM ĐỊNH            1
# TỈNH BÌNH THUẬN          1
# TỈNH ĐỒNG THÁP           1
# dtype: int64

# %%
#res = grad_2022.groupby(by=['total']).size().sort_values(ascending=False)

bins = np.arange(0,60,5)
plt.hist(grad_2022['total'],bins,color='gray',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Combined Scores')


plt.show()

# %%
# grad_natsci = grad_2022.dropna(subset=natural_sciences)         #this wont drop if all 3 columns are True, which we dont need => WRONG
# grad_socsci = grad_2022.dropna(subset=social_sciences)
# #grad_natsci.sort_values(by=['total'],ascending=False).head(50)
# print(grad_natsci.shape)
# print(grad_socsci.shape)
# print(grad_natsci.shape[0]+grad_socsci.shape[0]-grad_2022.shape[0])
# grad_natsci.head(10)
# Out:
# (318685, 12)
# (554090, 12)
# -122666
# (318685, 12)
#          sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 10  01000011   6.4     7.25        7.6    3.50     8.00      3.00      NaN
# 14  01000015   8.6     7.25        9.6    8.25     3.25      4.25      NaN
# 15  01000016   7.8     5.75        8.4    4.25     8.00      4.75      NaN
# 16  01000017   8.6     6.25        7.0    7.00     3.50      3.75      NaN
# 22  01000023   6.8     6.00        6.8    2.50     5.50      3.00      NaN
# 23  01000024   8.6     6.50        9.8    7.75     8.50      6.75      NaN
# 24  01000025   7.2     5.50        5.8    3.00     6.50      3.75      NaN
# 25  01000026   7.0     6.00        9.8    6.50     2.25      3.00      NaN
# 26  01000027   7.6     5.75        4.8    7.25     6.50      6.25      NaN
# 27  01000028   8.6     7.00        8.0    4.75     8.75      4.50      NaN
#
#     dia_li  gdcd               SGD  total
# 10     NaN   NaN  THÀNH PHỐ HÀ NỘI  35.75
# ...

# %%
is_natsci = (grad_2022[natural_sciences].any(axis='columns'))
is_socsci = (grad_2022[social_sciences].any(axis='columns'))
grad_natsci = grad_2022.loc[is_natsci,:]
grad_socsci = grad_2022.loc[is_socsci,:]
print(grad_natsci.shape)
print(grad_socsci.shape)
print(grad_natsci.shape[0] + grad_socsci.shape[0] - grad_2022.shape[0])
# Out:
# (329233, 12)
# (660073, 12)
# -6135

# %%
top_natsci = grad_natsci.sort_values(by=['total'],ascending=False)
top_natsci.head(100).groupby(by=['SGD']).size().sort_values(ascending=False)
# Out:
# SGD
# TỈNH NAM ĐỊNH            11
# THÀNH PHỐ HẢI PHÒNG      11
# TỈNH BÌNH DƯƠNG           8
# THÀNH PHỐ HỒ CHÍ MINH     7
# TỈNH VĨNH PHÚC            7
# TỈNH THÁI BÌNH            6
# TỈNH THANH HÓA            6
# THÀNH PHỐ HÀ NỘI          5
# TỈNH HÀ NAM               4
# TỈNH BẠC LIÊU             3
# TỈNH GIA LAI              3
# TỈNH VĨNH LONG            2
# TỈNH TIỀN GIANG           2
# TỈNH PHÚ THỌ              2
# TỈNH HƯNG YÊN             2
# TỈNH HẢI DƯƠNG            2
# TỈNH KHÁNH HÒA            2
# THÀNH PHỐ CẦN THƠ         1
# TỈNH THỪA THIÊN HUẾ       1
# TỈNH TUYÊN QUANG          1
# TỈNH ĐỒNG NAI             1
# TỈNH QUẢNG NGÃI           1
# TỈNH KIÊN GIANG           1
# TỈNH NINH THUẬN           1
# TỈNH NINH BÌNH            1
# TỈNH NGHỆ AN              1
# TỈNH LONG AN              1
# TỈNH BẾN TRE              1
# TỈNH BẮC NINH             1
# TỈNH BẮC GIANG            1
# TỈNH BÌNH ĐỊNH            1
# TỈNH BÌNH PHƯỚC           1
# TỈNH AN GIANG             1
# ...

# %%
bins = np.arange(0,60,5)
plt.hist(grad_natsci['total'],bins,color='blue',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Combined Scores')


plt.show()

# %%
top_socsci = grad_socsci.sort_values(by=['total'],ascending=False)
top_socsci.head(100).groupby(by=['SGD']).size().sort_values(ascending=False)
# Out:
# SGD
# THÀNH PHỐ HẢI PHÒNG     27
# TỈNH NAM ĐỊNH           15
# TỈNH VĨNH PHÚC          13
# THÀNH PHỐ HÀ NỘI         7
# TỈNH HÀ NAM              7
# TỈNH NINH BÌNH           4
# TỈNH KHÁNH HÒA           2
# TỈNH QUẢNG NINH          2
# TỈNH TIỀN GIANG          2
# TỈNH THANH HÓA           2
# TỈNH BẮC NINH            2
# TỈNH THÁI BÌNH           2
# TỈNH TUYÊN QUANG         1
# TỈNH THỪA THIÊN HUẾ      1
# TỈNH VĨNH LONG           1
# TỈNH THÁI NGUYÊN         1
# TỈNH ĐIỆN BIÊN           1
# TỈNH PHÚ THỌ             1
# TỈNH SÓC TRĂNG           1
# TỈNH QUẢNG NAM           1
# TỈNH NGHỆ AN             1
# TỈNH HẢI DƯƠNG           1
# TỈNH GIA LAI             1
# TỈNH BẮC GIANG           1
# TỈNH BÀ RỊA VŨNG TÀU     1
# TỈNH AN GIANG            1
# TỈNH ĐẮK LẮK             1
# dtype: int64

# %%
bins = np.arange(0,60,5)
plt.hist(grad_socsci['total'],bins,color='green',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Combined Scores')


plt.show()

# %%
cond = (grad_2022['sbd'] == '02070531')
grad_2022.loc[cond,:]
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 167052  02070531   8.8      3.5        9.6    8.25      5.0       4.5
#
#         lich_su  dia_li  gdcd                    SGD  total  a1_marking  \
# 167052      NaN     NaN   NaN  THÀNH PHỐ HỒ CHÍ MINH  39.65       26.65
#
#         a1_comb
# 167052    26.65

# %%
grad_2022.groupby(by=['SGD'])['ngoai_ngu'].median().sort_values(ascending=False)
# Out:
# SGD
# THÀNH PHỐ HỒ CHÍ MINH    6.6
# TỈNH BÌNH DƯƠNG          6.2
# THÀNH PHỐ ĐÀ NẴNG        5.8
# TỈNH BÀ RỊA VŨNG TÀU     5.8
# THÀNH PHỐ HÀ NỘI         5.8
# THÀNH PHỐ HẢI PHÒNG      5.6
# TỈNH VĨNH PHÚC           5.4
# TỈNH NAM ĐỊNH            5.4
# TỈNH NINH BÌNH           5.2
# TỈNH ĐỒNG NAI            5.2
# TỈNH BÌNH ĐỊNH           5.2
# TỈNH BẮC NINH            5.2
# TỈNH TIỀN GIANG          5.0
# TỈNH LONG AN             5.0
# TỈNH LÂM ĐỒNG            5.0
# TỈNH KHÁNH HÒA           5.0
# TỈNH QUẢNG NINH          5.0
# TỈNH AN GIANG            5.0
# TỈNH QUẢNG NGÃI          4.8
# TỈNH PHÚ THỌ             4.8
# TỈNH THÁI BÌNH           4.8
# TỈNH HẢI DƯƠNG           4.8
# TỈNH VĨNH LONG           4.8
# THÀNH PHỐ CẦN THƠ        4.8
# TỈNH ĐỒNG THÁP           4.8
# TỈNH BẮC GIANG           4.8
# TỈNH HÀ NAM              4.8
# TỈNH BÌNH THUẬN          4.8
# TỈNH BẠC LIÊU            4.8
# TỈNH BÌNH PHƯỚC          4.6
# TỈNH TÂY NINH            4.6
# TỈNH HÀ TĨNH             4.6
# ...

# %%
grad_natsci.groupby(by=['SGD'])['total'].median().sort_values(ascending=False)
# Out:
# SGD
# TỈNH NINH BÌNH           41.500
# TỈNH BÌNH DƯƠNG          41.350
# THÀNH PHỐ HẢI PHÒNG      41.300
# TỈNH VĨNH PHÚC           41.250
# TỈNH NAM ĐỊNH            41.100
# TỈNH TUYÊN QUANG         40.900
# TỈNH BẮC NINH            40.600
# TỈNH HÀ NAM              40.400
# TỈNH HÀ TĨNH             40.350
# TỈNH YÊN BÁI             40.350
# TỈNH LÀO CAI             40.200
# TỈNH PHÚ THỌ             40.200
# TỈNH BẮC GIANG           39.750
# TỈNH BÌNH ĐỊNH           39.600
# TỈNH HÒA BÌNH            39.500
# TỈNH LÂM ĐỒNG            39.350
# TỈNH HẢI DƯƠNG           39.300
# TỈNH VĨNH LONG           39.200
# TỈNH TIỀN GIANG          39.150
# TỈNH THÁI BÌNH           39.100
# TỈNH QUẢNG NINH          39.000
# TỈNH NGHỆ AN             39.000
# TỈNH BẠC LIÊU            38.900
# TỈNH AN GIANG            38.900
# TỈNH THỪA THIÊN HUẾ      38.650
# TỈNH THANH HÓA           38.600
# TỈNH SƠN LA              38.600
# TỈNH BÌNH THUẬN          38.550
# TỈNH QUẢNG NAM           38.450
# ...

# %%
grad_socsci.groupby(by=['SGD'])['total'].median().sort_values(ascending=False)
# Out:
# SGD
# THÀNH PHỐ HẢI PHÒNG      41.85
# TỈNH NINH BÌNH           41.80
# TỈNH NAM ĐỊNH            41.65
# TỈNH VĨNH PHÚC           41.55
# TỈNH BÌNH DƯƠNG          41.05
# TỈNH HÀ NAM              40.20
# TỈNH HÀ TĨNH             39.70
# TỈNH PHÚ THỌ             39.70
# TỈNH BẮC NINH            39.50
# TỈNH AN GIANG            39.35
# THÀNH PHỐ HỒ CHÍ MINH    38.90
# TỈNH BẠC LIÊU            38.80
# THÀNH PHỐ HÀ NỘI         38.75
# TỈNH TIỀN GIANG          38.75
# TỈNH HẢI DƯƠNG           38.55
# TỈNH BẮC GIANG           38.50
# TỈNH THÁI BÌNH           38.35
# TỈNH LÀO CAI             38.35
# TỈNH LÂM ĐỒNG            38.30
# TỈNH BÌNH ĐỊNH           38.10
# TỈNH VĨNH LONG           37.85
# TỈNH NGHỆ AN             37.65
# TỈNH TUYÊN QUANG         37.60
# TỈNH ĐỒNG THÁP           37.55
# THÀNH PHỐ CẦN THƠ        37.10
# TỈNH BÌNH THUẬN          37.05
# TỈNH BÀ RỊA VŨNG TÀU     37.00
# TỈNH THANH HÓA           37.00
# TỈNH LONG AN             36.95
# TỈNH THỪA THIÊN HUẾ      36.85
# ...
