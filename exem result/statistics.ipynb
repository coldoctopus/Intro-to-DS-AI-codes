# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
result = pd.read_csv("D:\GitHub\Intro-to-DS-AI-codes\exem result\gradelist raw.csv")
result = result.set_index('No.')
result = result.rename(columns={'Grade.1': 'Grade/10'})
result
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\PC\AppData\Local\Temp\ipykernel_16064\3141546929.py:1: SyntaxWarning: invalid escape sequence '\G'
#   result = pd.read_csv("D:\GitHub\Intro-to-DS-AI-codes\exem result\gradelist raw.csv")
#       Intake    VGU ID Last Names and Middle Names Names  Attempts  \
# No.
# 1    CSE2021  10421133                      Bui Le  Nhat         1
# 2    CSE2021  10421127               Bui Van Hoang    Vu         1
# 3    CSE2022  10422002                    Pham Duc    An         1
# 4    CSE2022  10422003                     Le Thai    An         1
# 5    CSE2022  10422004               Yamashita Tri    An         1
# ..       ...       ...                         ...   ...       ...
# 114  CSE2022  10422083                  Ta Le Khoi    Vi         1
# 115  CSE2022  10422084                 Nguyen Tuan  Viet         1
# ...

# %%
result.shape
# Out:
# (118, 18)

# %%
result.columns
# Out:
# Index(['Intake', 'VGU ID', 'Last Names and Middle Names', 'Names', 'Attempts',
#        'Emails', 'Grade', 'Note', 'Lab 1', 'Lab 2', 'Final (40%)',
#        'Project (40%)', 'Bonus', 'Total final', 'Grade/10', 'German',
#        'Rounded German', 'Note (project)'],
#       dtype='object')

# %%
final_grade = result.loc[:,['VGU ID','Grade']]
final_grade
# Out:
#        VGU ID  Grade
# No.
# 1    10421133    5.0
# 2    10421127    1.3
# 3    10422002    2.3
# 4    10422003    4.0
# 5    10422004    1.0
# ..        ...    ...
# 114  10422083    2.3
# 115  10422084    1.7
# 116  10422122    1.3
# 117  10421067    2.0
# 118  10422085    1.7
#
# [118 rows x 2 columns]

# %%
final_score = result.loc[:,['VGU ID','Grade/10']]
#final_score.sort_values(by=['Project (40%)'],ascending=False).tail(20)            
final_score.describe()
# Out:
#              VGU ID    Grade/10
# count  1.180000e+02  118.000000
# mean   1.024224e+07    7.394068
# std    1.348461e+06    2.406945
# min    1.741700e+04    0.000000
# 25%    1.042202e+07    7.000000
# 50%    1.042205e+07    8.100000
# 75%    1.042209e+07    8.975000
# max    1.042212e+07   10.000000

# %%
stat = result.groupby(by=['Grade']).size()
stat.index
# Out:
# Index([1.0, 1.3, 1.7, 2.0, 2.3, 2.7, 3.0, 3.3, 3.7, 4.0, 5.0], dtype='float64', name='Grade')

# %%
bins = np.arange(0,10,0.5)
plt.hist(result['Grade/10'],bins,color='gray',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Grade/10')


plt.show()

# %%
bins = np.arange(0,10,0.5)
plt.hist(result['Final (40%)'],bins,color='blue',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Final (40%)')


plt.show()

# %%
bins = np.arange(0,10,0.5)
plt.hist(result['Grade'],bins,color='blue',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Grade')


plt.show()

# %%
bins = np.arange(0,3,0.5)
plt.hist(result['Bonus'],bins,color='blue',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Bonus pts achieved')


plt.show()

# %%
bins = np.arange(0,10,0.5)
plt.hist(result['Total final'],bins,color='blue',edgecolor='black')

plt.xlabel('Score range')
plt.ylabel('Students')
plt.title('Total in Final')


plt.show()

# %%
result.groupby(by=['Bonus']).size()
# Out:
# Bonus
# 0.0    17
# 1.0    36
# 2.0     2
# dtype: int64

# %%
test = pd.read_excel("D:\bruhhh.xls.xlsx")
test
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test = pd.read_excel("D:\bruhhh.xls.xlsx")
#       2 test
#
# File d:\GitHub\Intro-to-DS-AI-codes\.venv\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...
